# %%
import numpy as np
import sympy as sym
import pydae.build_cffi as db
from pydae.grid_bpu import bpu

# %%
grid = bpu('bus3_trafo.json')

g_list = grid.dae['g'] 
h_dict = grid.dae['h_dict']
f_list = grid.dae['f']
x_list = grid.dae['x']
params_dict = grid.dae['params_dict']


sys = {'name':'bus3_trafo',
       'params_dict':params_dict,
       'f_list':f_list,
       'g_list':g_list,
       'x_list':x_list,
       'y_ini_list':grid.dae['y_ini'],
       'y_run_list':grid.dae['y_run'],
       'u_run_dict':grid.dae['u_run_dict'],
       'u_ini_dict':grid.dae['u_ini_dict'],
       'h_dict':h_dict}

dblr = db.builder(sys)
dblr.build()
# Out:
# Compilation time: 14.82 s

# %%
print(dblr.source)
# Out:
# void f_ini_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -p[19]*x[0] + p[9]*(x[1] - y[10]);
# out[1] = (1.0/2.0)*(-p[17]*(x[1] - y[10]) - y[4]*(p[18]*y[4] + y[0]*sin(x[0] - y[1])) - y[5]*(p[18]*y[5] + y[0]*cos(x[0] - y[1])) + y[9])/p[10];
# out[2] = (-x[2] - y[4]*(-p[15] + p[13]) + u[4])/p[11];
# out[3] = (-x[3] + y[5]*(-p[16] + p[14]))/p[12];
# out[4] = (y[8] - x[4])/p[22];
# out[5] = (x[4] - x[5])/p[24];
# out[6] = p[25]*(u[5] - y[6]) - 9.9999999999999995e-7*x[6];
# out[7] = 1 - y[10];
#
# }
# void g_ini_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -u[0]/p[0] + pow(y[0], 2)*p[1]/pow(p[3], 2) + y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) - p[8]*y[6]/p[0];
# out[1] = -u[1]/p[0] - pow(y[0], 2)*p[2]/pow(p[3], 2) + y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]) - p[8]*y[7]/p[0];
# out[2] = -u[2]/p[0] + y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + pow(y[2], 2)*(p[1] + p[4]);
# out[3] = -u[3]/p[0] + y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + pow(y[2], 2)*(-p[2] - p[5]);
# out[4] = p[18]*y[5] + y[0]*cos(x[0] - y[1]) + p[15]*y[4] - x[2];
# out[5] = p[18]*y[4] + y[0]*sin(x[0] - y[1]) - p[16]*y[5] - x[3];
# out[6] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]) - y[6];
# out[7] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]) - y[7];
# out[8] = p[20]*y[11] - y[8] + u[6] + x[6] - (x[1] - p[26])/p[21];
# out[9] = p[23]*(x[4] - x[5])/p[24] - y[9] + x[5];
# out[10] = x[1] - y[10];
# out[11] = p[28]*x[7] + p[27]*(1 - y[10]) - y[11];
#
# }
# void f_run_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -p[19]*x[0] + p[9]*(x[1] - y[10]);
# out[1] = (1.0/2.0)*(-p[17]*(x[1] - y[10]) - y[4]*(p[18]*y[4] + y[0]*sin(x[0] - y[1])) - y[5]*(p[18]*y[5] + y[0]*cos(x[0] - y[1])) + y[9])/p[10];
# out[2] = (-x[2] - y[4]*(-p[15] + p[13]) + u[4])/p[11];
# out[3] = (-x[3] + y[5]*(-p[16] + p[14]))/p[12];
# out[4] = (y[8] - x[4])/p[22];
# out[5] = (x[4] - x[5])/p[24];
# out[6] = p[25]*(u[5] - y[6]) - 9.9999999999999995e-7*x[6];
# out[7] = 1 - y[10];
#
# }
# void g_run_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -u[0]/p[0] + pow(y[0], 2)*p[1]/pow(p[3], 2) + y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) - p[8]*y[6]/p[0];
# out[1] = -u[1]/p[0] - pow(y[0], 2)*p[2]/pow(p[3], 2) + y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]) - p[8]*y[7]/p[0];
# out[2] = -u[2]/p[0] + y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + pow(y[2], 2)*(p[1] + p[4]);
# out[3] = -u[3]/p[0] + y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + pow(y[2], 2)*(-p[2] - p[5]);
# out[4] = p[18]*y[5] + y[0]*cos(x[0] - y[1]) + p[15]*y[4] - x[2];
# out[5] = p[18]*y[4] + y[0]*sin(x[0] - y[1]) - p[16]*y[5] - x[3];
# out[6] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]) - y[6];
# out[7] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]) - y[7];
# out[8] = p[20]*y[11] - y[8] + u[6] + x[6] - (x[1] - p[26])/p[21];
# out[9] = p[23]*(x[4] - x[5])/p[24] - y[9] + x[5];
# out[10] = x[1] - y[10];
# out[11] = p[28]*x[7] + p[27]*(1 - y[10]) - y[11];
#
# }
# void h_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = y[0];
# out[1] = y[2];
# out[2] = y[4]*(p[18]*y[4] + y[0]*sin(x[0] - y[1])) + y[5]*(p[18]*y[5] + y[0]*cos(x[0] - y[1]));
#
# }
# void de_jac_ini_xy_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[20] = 0.5*(-y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[28] = 0.5*(-y[4]*sin(x[0] - y[1]) - y[5]*cos(x[0] - y[1]))/p[10];
# out[29] = 0.5*(y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[32] = 0.5*(-2.0*p[18]*y[4] - y[0]*sin(x[0] - y[1]))/p[10];
# out[33] = 0.5*(-2.0*p[18]*y[5] - y[0]*cos(x[0] - y[1]))/p[10];
# out[168] = 2.0*y[0]*p[1]/pow(p[3], 2) + y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[169] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[170] = y[0]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[171] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[188] = -2.0*y[0]*p[2]/pow(p[3], 2) + y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[189] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[190] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[191] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[208] = y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[209] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[210] = y[0]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + 2.0*y[2]*(p[1] + p[4]);
# out[211] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[228] = y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[229] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[230] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + 2.0*y[2]*(-p[2] - p[5]);
# out[231] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[240] = -y[0]*sin(x[0] - y[1]);
# out[248] = cos(x[0] - y[1]);
# out[249] = y[0]*sin(x[0] - y[1]);
# out[260] = y[0]*cos(x[0] - y[1]);
# out[268] = sin(x[0] - y[1]);
# out[269] = -y[0]*cos(x[0] - y[1]);
# out[280] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]);
# out[288] = y[4]*sin(x[0] - y[1]) + y[5]*cos(x[0] - y[1]);
# out[289] = -y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]);
# out[292] = y[0]*sin(x[0] - y[1]);
# out[293] = y[0]*cos(x[0] - y[1]);
# out[300] = -y[0]*y[4]*sin(x[0] - y[1]) - y[0]*y[5]*cos(x[0] - y[1]);
# out[308] = y[4]*cos(x[0] - y[1]) - y[5]*sin(x[0] - y[1]);
# out[309] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]);
# out[312] = y[0]*cos(x[0] - y[1]);
# out[313] = -y[0]*sin(x[0] - y[1]);
#
# }
#
# void de_jac_ini_up_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -p[19];
# out[1] = p[9];
# out[18] = -p[9];
# out[21] = -0.5*p[17]/p[10];
# out[37] = 0.5/p[10];
# out[38] = 0.5*p[17]/p[10];
# out[42] = -1/p[11];
# out[52] = (p[15] - p[13])/p[11];
# out[63] = -1/p[12];
# out[73] = (-p[16] + p[14])/p[12];
# out[84] = -1/p[22];
# out[96] = 1.0/p[22];
# out[104] = 1.0/p[24];
# out[105] = -1/p[24];
# out[134] = -p[25];
# out[174] = -p[8]/p[0];
# out[195] = -p[8]/p[0];
# out[252] = p[15];
# out[253] = p[18];
# out[272] = p[18];
# out[273] = -p[16];
# out[321] = -1/p[21];
# out[339] = p[20];
# out[344] = p[23]/p[24];
# out[345] = -p[23]/p[24] + 1.0;
# out[387] = p[28];
# out[398] = -p[27];
#
# }
#
# void de_jac_ini_num_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[126] = -9.9999999999999995e-7;
# out[158] = -1.0;
# out[242] = -1.0;
# out[263] = -1.0;
# out[294] = -1.0;
# out[315] = -1.0;
# out[326] = 1.0;
# out[336] = -1.0;
# out[357] = -1.0;
# out[361] = 1.0;
# out[378] = -1.0;
# out[399] = -1.0;
#
# }
#
# void sp_jac_ini_xy_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[3] = 0.5*(-y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[5] = 0.5*(-y[4]*sin(x[0] - y[1]) - y[5]*cos(x[0] - y[1]))/p[10];
# out[6] = 0.5*(y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[7] = 0.5*(-2.0*p[18]*y[4] - y[0]*sin(x[0] - y[1]))/p[10];
# out[8] = 0.5*(-2.0*p[18]*y[5] - y[0]*cos(x[0] - y[1]))/p[10];
# out[22] = 2.0*y[0]*p[1]/pow(p[3], 2) + y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[23] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[24] = y[0]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[25] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[27] = -2.0*y[0]*p[2]/pow(p[3], 2) + y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[28] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[29] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[30] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[32] = y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[33] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[34] = y[0]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + 2.0*y[2]*(p[1] + p[4]);
# out[35] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[36] = y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[37] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[38] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + 2.0*y[2]*(-p[2] - p[5]);
# out[39] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[40] = -y[0]*sin(x[0] - y[1]);
# out[42] = cos(x[0] - y[1]);
# out[43] = y[0]*sin(x[0] - y[1]);
# out[46] = y[0]*cos(x[0] - y[1]);
# out[48] = sin(x[0] - y[1]);
# out[49] = -y[0]*cos(x[0] - y[1]);
# out[52] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]);
# out[53] = y[4]*sin(x[0] - y[1]) + y[5]*cos(x[0] - y[1]);
# out[54] = -y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]);
# out[55] = y[0]*sin(x[0] - y[1]);
# out[56] = y[0]*cos(x[0] - y[1]);
# out[58] = -y[0]*y[4]*sin(x[0] - y[1]) - y[0]*y[5]*cos(x[0] - y[1]);
# out[59] = y[4]*cos(x[0] - y[1]) - y[5]*sin(x[0] - y[1]);
# out[60] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]);
# out[61] = y[0]*cos(x[0] - y[1]);
# out[62] = -y[0]*sin(x[0] - y[1]);
#
# }
#
# void sp_jac_ini_up_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -p[19];
# out[1] = p[9];
# out[2] = -p[9];
# out[4] = -0.5*p[17]/p[10];
# out[9] = 0.5/p[10];
# out[10] = 0.5*p[17]/p[10];
# out[11] = -1/p[11];
# out[12] = (p[15] - p[13])/p[11];
# out[13] = -1/p[12];
# out[14] = (-p[16] + p[14])/p[12];
# out[15] = -1/p[22];
# out[16] = 1.0/p[22];
# out[17] = 1.0/p[24];
# out[18] = -1/p[24];
# out[20] = -p[25];
# out[26] = -p[8]/p[0];
# out[31] = -p[8]/p[0];
# out[44] = p[15];
# out[45] = p[18];
# out[50] = p[18];
# out[51] = -p[16];
# out[64] = -1/p[21];
# out[67] = p[20];
# out[68] = p[23]/p[24];
# out[69] = -p[23]/p[24] + 1.0;
# out[73] = p[28];
# out[74] = -p[27];
#
# }
#
# void sp_jac_ini_num_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[19] = -9.9999999999999995e-7;
# out[21] = -1.0;
# out[41] = -1.0;
# out[47] = -1.0;
# out[57] = -1.0;
# out[63] = -1.0;
# out[65] = 1.0;
# out[66] = -1.0;
# out[70] = -1.0;
# out[71] = 1.0;
# out[72] = -1.0;
# out[75] = -1.0;
#
# }
#
# void de_jac_run_xy_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[20] = 0.5*(-y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[28] = 0.5*(-y[4]*sin(x[0] - y[1]) - y[5]*cos(x[0] - y[1]))/p[10];
# out[29] = 0.5*(y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[32] = 0.5*(-2.0*p[18]*y[4] - y[0]*sin(x[0] - y[1]))/p[10];
# out[33] = 0.5*(-2.0*p[18]*y[5] - y[0]*cos(x[0] - y[1]))/p[10];
# out[168] = 2.0*y[0]*p[1]/pow(p[3], 2) + y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[169] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[170] = y[0]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[171] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[188] = -2.0*y[0]*p[2]/pow(p[3], 2) + y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[189] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[190] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[191] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[208] = y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[209] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[210] = y[0]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + 2.0*y[2]*(p[1] + p[4]);
# out[211] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[228] = y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[229] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[230] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + 2.0*y[2]*(-p[2] - p[5]);
# out[231] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[240] = -y[0]*sin(x[0] - y[1]);
# out[248] = cos(x[0] - y[1]);
# out[249] = y[0]*sin(x[0] - y[1]);
# out[260] = y[0]*cos(x[0] - y[1]);
# out[268] = sin(x[0] - y[1]);
# out[269] = -y[0]*cos(x[0] - y[1]);
# out[280] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]);
# out[288] = y[4]*sin(x[0] - y[1]) + y[5]*cos(x[0] - y[1]);
# out[289] = -y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]);
# out[292] = y[0]*sin(x[0] - y[1]);
# out[293] = y[0]*cos(x[0] - y[1]);
# out[300] = -y[0]*y[4]*sin(x[0] - y[1]) - y[0]*y[5]*cos(x[0] - y[1]);
# out[308] = y[4]*cos(x[0] - y[1]) - y[5]*sin(x[0] - y[1]);
# out[309] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]);
# out[312] = y[0]*cos(x[0] - y[1]);
# out[313] = -y[0]*sin(x[0] - y[1]);
#
# }
#
# void de_jac_run_up_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -p[19];
# out[1] = p[9];
# out[18] = -p[9];
# out[21] = -0.5*p[17]/p[10];
# out[37] = 0.5/p[10];
# out[38] = 0.5*p[17]/p[10];
# out[42] = -1/p[11];
# out[52] = (p[15] - p[13])/p[11];
# out[63] = -1/p[12];
# out[73] = (-p[16] + p[14])/p[12];
# out[84] = -1/p[22];
# out[96] = 1.0/p[22];
# out[104] = 1.0/p[24];
# out[105] = -1/p[24];
# out[134] = -p[25];
# out[174] = -p[8]/p[0];
# out[195] = -p[8]/p[0];
# out[252] = p[15];
# out[253] = p[18];
# out[272] = p[18];
# out[273] = -p[16];
# out[321] = -1/p[21];
# out[339] = p[20];
# out[344] = p[23]/p[24];
# out[345] = -p[23]/p[24] + 1.0;
# out[387] = p[28];
# out[398] = -p[27];
#
# }
#
# void de_jac_run_num_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[126] = -9.9999999999999995e-7;
# out[158] = -1.0;
# out[242] = -1.0;
# out[263] = -1.0;
# out[294] = -1.0;
# out[315] = -1.0;
# out[326] = 1.0;
# out[336] = -1.0;
# out[357] = -1.0;
# out[361] = 1.0;
# out[378] = -1.0;
# out[399] = -1.0;
#
# }
#
# void sp_jac_run_xy_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[3] = 0.5*(-y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[5] = 0.5*(-y[4]*sin(x[0] - y[1]) - y[5]*cos(x[0] - y[1]))/p[10];
# out[6] = 0.5*(y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[7] = 0.5*(-2.0*p[18]*y[4] - y[0]*sin(x[0] - y[1]))/p[10];
# out[8] = 0.5*(-2.0*p[18]*y[5] - y[0]*cos(x[0] - y[1]))/p[10];
# out[22] = 2.0*y[0]*p[1]/pow(p[3], 2) + y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[23] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[24] = y[0]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[25] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[27] = -2.0*y[0]*p[2]/pow(p[3], 2) + y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[28] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[29] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[30] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[32] = y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[33] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[34] = y[0]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + 2.0*y[2]*(p[1] + p[4]);
# out[35] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[36] = y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[37] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[38] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + 2.0*y[2]*(-p[2] - p[5]);
# out[39] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[40] = -y[0]*sin(x[0] - y[1]);
# out[42] = cos(x[0] - y[1]);
# out[43] = y[0]*sin(x[0] - y[1]);
# out[46] = y[0]*cos(x[0] - y[1]);
# out[48] = sin(x[0] - y[1]);
# out[49] = -y[0]*cos(x[0] - y[1]);
# out[52] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]);
# out[53] = y[4]*sin(x[0] - y[1]) + y[5]*cos(x[0] - y[1]);
# out[54] = -y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]);
# out[55] = y[0]*sin(x[0] - y[1]);
# out[56] = y[0]*cos(x[0] - y[1]);
# out[58] = -y[0]*y[4]*sin(x[0] - y[1]) - y[0]*y[5]*cos(x[0] - y[1]);
# out[59] = y[4]*cos(x[0] - y[1]) - y[5]*sin(x[0] - y[1]);
# out[60] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]);
# out[61] = y[0]*cos(x[0] - y[1]);
# out[62] = -y[0]*sin(x[0] - y[1]);
#
# }
#
# void sp_jac_run_up_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = -p[19];
# out[1] = p[9];
# out[2] = -p[9];
# out[4] = -0.5*p[17]/p[10];
# out[9] = 0.5/p[10];
# out[10] = 0.5*p[17]/p[10];
# out[11] = -1/p[11];
# out[12] = (p[15] - p[13])/p[11];
# out[13] = -1/p[12];
# out[14] = (-p[16] + p[14])/p[12];
# out[15] = -1/p[22];
# out[16] = 1.0/p[22];
# out[17] = 1.0/p[24];
# out[18] = -1/p[24];
# out[20] = -p[25];
# out[26] = -p[8]/p[0];
# out[31] = -p[8]/p[0];
# out[44] = p[15];
# out[45] = p[18];
# out[50] = p[18];
# out[51] = -p[16];
# out[64] = -1/p[21];
# out[67] = p[20];
# out[68] = p[23]/p[24];
# out[69] = -p[23]/p[24] + 1.0;
# out[73] = p[28];
# out[74] = -p[27];
#
# }
#
# void sp_jac_run_num_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[19] = -9.9999999999999995e-7;
# out[21] = -1.0;
# out[41] = -1.0;
# out[47] = -1.0;
# out[57] = -1.0;
# out[63] = -1.0;
# out[65] = 1.0;
# out[66] = -1.0;
# out[70] = -1.0;
# out[71] = 1.0;
# out[72] = -1.0;
# out[75] = -1.0;
#
# }
#
# void de_jac_trap_xy_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[20] = -0.25*Dt*(-y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[28] = -0.25*Dt*(-y[4]*sin(x[0] - y[1]) - y[5]*cos(x[0] - y[1]))/p[10];
# out[29] = -0.25*Dt*(y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[32] = -0.25*Dt*(-2.0*p[18]*y[4] - y[0]*sin(x[0] - y[1]))/p[10];
# out[33] = -0.25*Dt*(-2.0*p[18]*y[5] - y[0]*cos(x[0] - y[1]))/p[10];
# out[168] = 2.0*y[0]*p[1]/pow(p[3], 2) + y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[169] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[170] = y[0]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[171] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[188] = -2.0*y[0]*p[2]/pow(p[3], 2) + y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[189] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[190] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[191] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[208] = y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[209] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[210] = y[0]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + 2.0*y[2]*(p[1] + p[4]);
# out[211] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[228] = y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[229] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[230] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + 2.0*y[2]*(-p[2] - p[5]);
# out[231] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[240] = -y[0]*sin(x[0] - y[1]);
# out[248] = cos(x[0] - y[1]);
# out[249] = y[0]*sin(x[0] - y[1]);
# out[260] = y[0]*cos(x[0] - y[1]);
# out[268] = sin(x[0] - y[1]);
# out[269] = -y[0]*cos(x[0] - y[1]);
# out[280] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]);
# out[288] = y[4]*sin(x[0] - y[1]) + y[5]*cos(x[0] - y[1]);
# out[289] = -y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]);
# out[292] = y[0]*sin(x[0] - y[1]);
# out[293] = y[0]*cos(x[0] - y[1]);
# out[300] = -y[0]*y[4]*sin(x[0] - y[1]) - y[0]*y[5]*cos(x[0] - y[1]);
# out[308] = y[4]*cos(x[0] - y[1]) - y[5]*sin(x[0] - y[1]);
# out[309] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]);
# out[312] = y[0]*cos(x[0] - y[1]);
# out[313] = -y[0]*sin(x[0] - y[1]);
#
# }
#
# void de_jac_trap_up_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = 0.5*Dt*p[19] + 1.0;
# out[1] = -0.5*Dt*p[9];
# out[18] = 0.5*Dt*p[9];
# out[21] = 0.25*p[17]*Dt/p[10] + 1.0;
# out[37] = -0.25*Dt/p[10];
# out[38] = -0.25*p[17]*Dt/p[10];
# out[42] = 0.5*Dt/p[11] + 1.0;
# out[52] = -0.5*Dt*(p[15] - p[13])/p[11];
# out[63] = 0.5*Dt/p[12] + 1.0;
# out[73] = -0.5*Dt*(-p[16] + p[14])/p[12];
# out[84] = 0.5*Dt/p[22] + 1.0;
# out[96] = -0.5*Dt/p[22];
# out[104] = -0.5*Dt/p[24];
# out[105] = 0.5*Dt/p[24] + 1.0;
# out[126] = 4.9999999999999998e-7*Dt + 1.0;
# out[134] = 0.5*Dt*p[25];
# out[158] = 0.5*Dt;
# out[174] = -p[8]/p[0];
# out[195] = -p[8]/p[0];
# out[252] = p[15];
# out[253] = p[18];
# out[272] = p[18];
# out[273] = -p[16];
# out[321] = -1/p[21];
# out[339] = p[20];
# out[344] = p[23]/p[24];
# out[345] = -p[23]/p[24] + 1.0;
# out[387] = p[28];
# out[398] = -p[27];
#
# }
#
# void de_jac_trap_num_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[147] = 1.0;
# out[242] = -1.0;
# out[263] = -1.0;
# out[294] = -1.0;
# out[315] = -1.0;
# out[326] = 1.0;
# out[336] = -1.0;
# out[357] = -1.0;
# out[361] = 1.0;
# out[378] = -1.0;
# out[399] = -1.0;
#
# }
#
# void sp_jac_trap_xy_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[3] = -0.25*Dt*(-y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[5] = -0.25*Dt*(-y[4]*sin(x[0] - y[1]) - y[5]*cos(x[0] - y[1]))/p[10];
# out[6] = -0.25*Dt*(y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]))/p[10];
# out[7] = -0.25*Dt*(-2.0*p[18]*y[4] - y[0]*sin(x[0] - y[1]))/p[10];
# out[8] = -0.25*Dt*(-2.0*p[18]*y[5] - y[0]*cos(x[0] - y[1]))/p[10];
# out[23] = 2.0*y[0]*p[1]/pow(p[3], 2) + y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[24] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[25] = y[0]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[26] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[28] = -2.0*y[0]*p[2]/pow(p[3], 2) + y[2]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[29] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[30] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[31] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[33] = y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[34] = y[0]*y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[35] = y[0]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]) + 2.0*y[2]*(p[1] + p[4]);
# out[36] = y[0]*y[2]*(-p[2]*cos(y[1] - y[3])/p[3] - p[1]*sin(y[1] - y[3])/p[3]);
# out[37] = y[2]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]);
# out[38] = y[0]*y[2]*(-p[2]*sin(y[1] - y[3])/p[3] + p[1]*cos(y[1] - y[3])/p[3]);
# out[39] = y[0]*(p[2]*cos(y[1] - y[3])/p[3] + p[1]*sin(y[1] - y[3])/p[3]) + 2.0*y[2]*(-p[2] - p[5]);
# out[40] = y[0]*y[2]*(p[2]*sin(y[1] - y[3])/p[3] - p[1]*cos(y[1] - y[3])/p[3]);
# out[41] = -y[0]*sin(x[0] - y[1]);
# out[43] = cos(x[0] - y[1]);
# out[44] = y[0]*sin(x[0] - y[1]);
# out[47] = y[0]*cos(x[0] - y[1]);
# out[49] = sin(x[0] - y[1]);
# out[50] = -y[0]*cos(x[0] - y[1]);
# out[53] = y[0]*y[4]*cos(x[0] - y[1]) - y[0]*y[5]*sin(x[0] - y[1]);
# out[54] = y[4]*sin(x[0] - y[1]) + y[5]*cos(x[0] - y[1]);
# out[55] = -y[0]*y[4]*cos(x[0] - y[1]) + y[0]*y[5]*sin(x[0] - y[1]);
# out[56] = y[0]*sin(x[0] - y[1]);
# out[57] = y[0]*cos(x[0] - y[1]);
# out[59] = -y[0]*y[4]*sin(x[0] - y[1]) - y[0]*y[5]*cos(x[0] - y[1]);
# out[60] = y[4]*cos(x[0] - y[1]) - y[5]*sin(x[0] - y[1]);
# out[61] = y[0]*y[4]*sin(x[0] - y[1]) + y[0]*y[5]*cos(x[0] - y[1]);
# out[62] = y[0]*cos(x[0] - y[1]);
# out[63] = -y[0]*sin(x[0] - y[1]);
#
# }
#
# void sp_jac_trap_up_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[0] = 0.5*Dt*p[19] + 1.0;
# out[1] = -0.5*Dt*p[9];
# out[2] = 0.5*Dt*p[9];
# out[4] = 0.25*p[17]*Dt/p[10] + 1.0;
# out[9] = -0.25*Dt/p[10];
# out[10] = -0.25*p[17]*Dt/p[10];
# out[11] = 0.5*Dt/p[11] + 1.0;
# out[12] = -0.5*Dt*(p[15] - p[13])/p[11];
# out[13] = 0.5*Dt/p[12] + 1.0;
# out[14] = -0.5*Dt*(-p[16] + p[14])/p[12];
# out[15] = 0.5*Dt/p[22] + 1.0;
# out[16] = -0.5*Dt/p[22];
# out[17] = -0.5*Dt/p[24];
# out[18] = 0.5*Dt/p[24] + 1.0;
# out[19] = 4.9999999999999998e-7*Dt + 1.0;
# out[20] = 0.5*Dt*p[25];
# out[22] = 0.5*Dt;
# out[27] = -p[8]/p[0];
# out[32] = -p[8]/p[0];
# out[45] = p[15];
# out[46] = p[18];
# out[51] = p[18];
# out[52] = -p[16];
# out[65] = -1/p[21];
# out[68] = p[20];
# out[69] = p[23]/p[24];
# out[70] = -p[23]/p[24] + 1.0;
# out[74] = p[28];
# out[75] = -p[27];
#
# }
#
# void sp_jac_trap_num_eval(double *out,double *x,double *y,double *u,double *p,double Dt){
#
# out[21] = 1.0;
# out[42] = -1.0;
# out[48] = -1.0;
# out[58] = -1.0;
# out[64] = -1.0;
# out[66] = 1.0;
# out[67] = -1.0;
# out[71] = -1.0;
# out[72] = 1.0;
# out[73] = -1.0;
# out[76] = -1.0;
#
# }

# %%
len(grid.dae['y_ini'])
# Out:
# 12

# %%
params_dict
# Out:
# {'S_base': 100000000.0,
#  'g_cc_1_2': 0.0,
#  'b_cc_1_2': -200.0,
#  'tap_1_2': 1.0,
#  'sg_2_2': 4e-06,
#  'sb_2_2': -0.0,
#  'U_1_n': 20000.0,
#  'U_2_n': 20000.0,
#  'S_n_1': 900000000.0,
#  'Omega_b_1': 314.1592653589793,
#  'H_1': 5.0,
#  'T1d0_1': 8.0,
#  'T1q0_1': 0.4,
#  'X_d_1': 1.8,
#  'X_q_1': 1.7,
#  'X1d_1': 0.3,
#  'X1q_1': 0.55,
#  'D_1': 1.0,
#  'R_a_1': 0.01,
#  'K_delta_1': 0.01,
#  'K_sec_1': 1,
#  'Droop_1': 0.05,
#  'T_gov_1_1': 1.0,
#  'T_gov_2_1': 2.0,
#  'T_gov_3_1': 10.0,
#  'K_imw_1': 0.1,
#  'omega_ref_1': 1.0,
#  'K_p_agc': 1.0,
#  'K_i_agc': 0.1}
